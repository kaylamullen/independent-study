# %% [markdown]
# # Analysis of algorithm results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Diff dasher ratios

# %%
sd = pd.read_csv('results/smartdispatch/allcenter-D1-T5.csv').sort_values(by='ratio_dashers_tasks')
b = pd.read_csv('results/baseline/allcenter-D1-T5.csv').sort_values(by='ratio_dashers_tasks')

# %%
sd
# Out:
#     num_dashers  num_tasks  ratio_dashers_tasks  num_events  total_reward  \
# 35           10        750             0.013333        7541          1840
# 28           10        500             0.020000        4923          1266
# 21           10        400             0.025000        4389          1016
# 14           10        300             0.033333        5372           735
# 7            10        200             0.050000        4393           494
# 36           50        750             0.066667       21509          1874
# 0            10        100             0.100000        4824           241
# 29           50        500             0.100000       23710          1262
# 22           50        400             0.125000       21627          1002
# 37          100        750             0.133333       45505          1863
# 15           50        300             0.166667       20980           745
# 30          100        500             0.200000       46712          1289
# 23          100        400             0.250000       45887          1003
# 8            50        200             0.250000       22382           481
# 38          200        750             0.266667       88747          1848
# 16          100        300             0.333333       45062           762
# 39          300        750             0.400000      128925          1893
# 31          200        500             0.400000       87803          1266
# 9           100        200             0.500000       45785           485
# 1            50        100             0.500000       24717           252
# 24          200        400             0.500000       87002          1016
# 40          400        750             0.533333      172080          1831
# 32          300        500             0.600000      129949          1277
# 41          500        750             0.666667      218310          1900
# 17          200        300             0.666667       89206           736
# 25          300        400             0.750000      122478           960
# 33          400        500             0.800000      168300          1243
# 18          300        300             1.000000      128071           783
# 2           100        100             1.000000       46610           261
# 34          500        500             1.000000      206469          1275
# 10          200        200             1.000000       92215           489
# 26          400        400             1.000000      173162           998
# 27          500        400             1.250000      211075           996
# 19          400        300             1.333333      175433           746
# 11          300        200             1.500000      131386           506
# 20          500        300             1.666667      212760           777
# 3           200        100             2.000000       88990           241
# 12          400        200             2.000000      169888           474
# 13          500        200             2.500000      215195           475
# 4           300        100             3.000000      129260           219
# 5           400        100             4.000000      172207           268
# 6           500        100             5.000000      215651           266
#
#     pct_total_possible_reward
# 35                  100.00000
# 28                  100.00000
# 21                  100.00000
# 14                   99.86413
# 7                   100.00000
# 36                  100.00000
# 0                   100.00000
# 29                  100.00000
# 22                  100.00000
# 37                  100.00000
# 15                  100.00000
# 30                  100.00000
# 23                  100.00000
# 8                   100.00000
# 38                  100.00000
# 16                  100.00000
# 39                  100.00000
# 31                  100.00000
# 9                   100.00000
# 1                   100.00000
# 24                  100.00000
# 40                  100.00000
# 32                  100.00000
# 41                  100.00000
# 17                  100.00000
# 25                  100.00000
# 33                  100.00000
# 18                  100.00000
# 2                   100.00000
# 34                  100.00000
# 10                  100.00000
# 26                  100.00000
# 27                  100.00000
# 19                  100.00000
# 11                  100.00000
# 20                  100.00000
# 3                   100.00000
# 12                  100.00000
# 13                  100.00000
# 4                   100.00000
# 5                   100.00000
# 6                   100.00000

# %%
b.head()
# Out:
#     num_dashers  num_tasks  ratio_dashers_tasks  num_events  total_reward  \
# 35           10        750             0.013333        1757          1025
# 28           10        500             0.020000        1535           763
# 21           10        400             0.025000        1439           639
# 14           10        300             0.033333        1344           533
# 7            10        200             0.050000        1226           412
#
#     pct_total_possible_reward
# 35                  54.146857
# 28                  62.695152
# 21                  61.265580
# 14                  70.131579
# 7                   83.400810

# %%
# plot lines
plt.plot(sd['ratio_dashers_tasks'], sd['pct_total_possible_reward'], label = "smart dispatch")
plt.plot(b["ratio_dashers_tasks"], b['pct_total_possible_reward'], label = "baseline")
plt.xlabel("ratio of dashers to tasks")
plt.ylabel("percent of total possible reward")
plt.title("Pct Total Possible Reward vs. Ratio of Dashers to Tasks: Low reward")
plt.legend()
plt.show()

# %%
# plot lines
plt.plot(sd['ratio_dashers_tasks'], sd['pct_total_possible_reward'], label = "smart dispatch")
plt.plot(b["ratio_dashers_tasks"], b['pct_total_possible_reward'], label = "baseline")
plt.xlim(0, 0.2)
plt.xlabel("ratio of dashers to tasks")
plt.ylabel("percent of total possible reward")
plt.title("Pct Total Possible Reward vs. Ratio of Dashers to Tasks: Low reward")
plt.legend()
plt.show()

# %%
# plot lines
plt.plot(sd['ratio_dashers_tasks'], sd['pct_total_possible_reward'], label = "smart dispatch")
plt.plot(b["ratio_dashers_tasks"], b['pct_total_possible_reward'], label = "baseline")
plt.xlim(-0.001, 0.1)
plt.xlabel("ratio of dashers to tasks")
plt.ylabel("percent of total possible reward")
plt.title("Pct Total Possible Reward vs. Ratio of Dashers to Tasks: Low reward")
plt.legend()
plt.show()

# %%
# plot lines
plt.plot(sd['ratio_dashers_tasks'], sd['pct_total_possible_reward'], label = "smart dispatch")
plt.plot(b["ratio_dashers_tasks"], b['pct_total_possible_reward'], label = "baseline")
plt.xlim(0, 0.01)
plt.xlabel("ratio of dashers to tasks")
plt.ylabel("percent of total possible reward")
plt.title("Percent of Total Possible Reward vs. Ratio of Dashers to Tasks: D1-T200")
plt.legend()
plt.show()
